# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(8,7))
df[df >0.9]=np.nan
df
# Out:
#           0         1         2         3         4         5         6
# 0 -0.040495       NaN -0.571807  0.225464 -1.890995  0.478840 -0.818483
# 1 -0.395074 -0.005092  0.114947 -0.723108 -1.577731  0.155245       NaN
# 2  0.074364 -1.709254       NaN  0.375773       NaN       NaN -0.042733
# 3 -1.143116       NaN  0.074440  0.146072  0.221990 -1.212188  0.162263
# 4  0.540532       NaN -0.148459 -0.515014  0.264934 -0.836691 -0.125996
# 5  0.039792 -0.997741       NaN -0.089095  0.713526 -0.110521  0.497316
# 6 -0.524320  0.355579 -0.699547 -1.346776 -0.545358       NaN -2.071598
# 7  0.627577  0.280165  0.131670  0.038347 -0.257383  0.664601 -1.072826

# %%
print(df.isnull())
# Out:
#        0      1      2      3      4      5      6
# 0  False   True  False  False  False  False  False
# 1  False  False  False  False  False  False   True
# 2  False  False   True  False   True   True  False
# 3  False   True  False  False  False  False  False
# 4  False   True  False  False  False  False  False
# 5  False  False   True  False  False  False  False
# 6  False  False  False  False  False   True  False
# 7  False  False  False  False  False  False  False

# %%
print(df.isnull().sum())
# Out:
# 0    0
# 1    3
# 2    2
# 3    0
# 4    1
# 5    2
# 6    1
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 9

# %%
df.index = ['a','b','c','d','e','f','g','h']
df
# Out:
#           0         1         2         3         4         5         6
# a -0.040495       NaN -0.571807  0.225464 -1.890995  0.478840 -0.818483
# b -0.395074 -0.005092  0.114947 -0.723108 -1.577731  0.155245       NaN
# c  0.074364 -1.709254       NaN  0.375773       NaN       NaN -0.042733
# d -1.143116       NaN  0.074440  0.146072  0.221990 -1.212188  0.162263
# e  0.540532       NaN -0.148459 -0.515014  0.264934 -0.836691 -0.125996
# f  0.039792 -0.997741       NaN -0.089095  0.713526 -0.110521  0.497316
# g -0.524320  0.355579 -0.699547 -1.346776 -0.545358       NaN -2.071598
# h  0.627577  0.280165  0.131670  0.038347 -0.257383  0.664601 -1.072826

# %%
df.dropna()
# Out:
#           0         1        2         3         4         5         6
# h  0.627577  0.280165  0.13167  0.038347 -0.257383  0.664601 -1.072826

# %%
df.fillna(0,inplace=True)
print(df)
# Out:
#           0         1         2         3         4         5         6
# a -0.040495  0.000000 -0.571807  0.225464 -1.890995  0.478840 -0.818483
# b -0.395074 -0.005092  0.114947 -0.723108 -1.577731  0.155245  0.000000
# c  0.074364 -1.709254  0.000000  0.375773  0.000000  0.000000 -0.042733
# d -1.143116  0.000000  0.074440  0.146072  0.221990 -1.212188  0.162263
# e  0.540532  0.000000 -0.148459 -0.515014  0.264934 -0.836691 -0.125996
# f  0.039792 -0.997741  0.000000 -0.089095  0.713526 -0.110521  0.497316
# g -0.524320  0.355579 -0.699547 -1.346776 -0.545358  0.000000 -2.071598
# h  0.627577  0.280165  0.131670  0.038347 -0.257383  0.664601 -1.072826

# %%
df = pd.DataFrame(np.random.randn(7,6))
df[df>0.9]=np.nan
df
# Out:
#           0         1         2         3         4         5
# 0 -0.730230       NaN  0.471590  0.580039  0.343358  0.895044
# 1  0.002322  0.047737  0.544850 -0.167486  0.232662  0.824829
# 2  0.068419       NaN -0.775442 -0.207548       NaN  0.111815
# 3  0.550436 -1.312570  0.604714  0.219919       NaN  0.385542
# 4 -0.617188  0.107766 -1.285546 -0.056190 -2.064753 -0.988643
# 5  0.871939  0.159180  0.519096 -1.226277       NaN -0.457093
# 6 -0.954387 -0.968952 -0.880563 -0.159673  0.653278       NaN

# %%
df[0].fillna(df[2].mean(),inplace=True)
df
# Out:
#           0         1         2         3         4         5
# 0 -0.730230       NaN  0.471590  0.580039  0.343358  0.895044
# 1  0.002322  0.047737  0.544850 -0.167486  0.232662  0.824829
# 2  0.068419       NaN -0.775442 -0.207548       NaN  0.111815
# 3  0.550436 -1.312570  0.604714  0.219919       NaN  0.385542
# 4 -0.617188  0.107766 -1.285546 -0.056190 -2.064753 -0.988643
# 5  0.871939  0.159180  0.519096 -1.226277       NaN -0.457093
# 6 -0.954387 -0.968952 -0.880563 -0.159673  0.653278       NaN

# %%
for column_name in df:
    df[column_name].fillna(df[column_name].mean(),inplace=True)
df
# Out:
#           0         1         2         3         4         5
# 0 -0.730230 -0.393368  0.471590  0.580039  0.343358  0.895044
# 1  0.002322  0.047737  0.544850 -0.167486  0.232662  0.824829
# 2  0.068419 -0.393368 -0.775442 -0.207548 -0.208864  0.111815
# 3  0.550436 -1.312570  0.604714  0.219919 -0.208864  0.385542
# 4 -0.617188  0.107766 -1.285546 -0.056190 -2.064753 -0.988643
# 5  0.871939  0.159180  0.519096 -1.226277 -0.208864 -0.457093
# 6 -0.954387 -0.968952 -0.880563 -0.159673  0.653278  0.128582

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)

# %%
df = pd.read_csv('Sberbank Housing Market.csv')

# %%
df.shape
# Out:
# (30471, 292)

# %%
df.dtypes
# Out:
# id                      int64
# timestamp              object
# full_sq                 int64
# life_sq               float64
# floor                 float64
#                        ...
# mosque_count_5000       int64
# leisure_count_5000      int64
# sport_count_5000        int64
# market_count_5000       int64
# price_doc               int64
# Length: 292, dtype: object

# %%
from pandas.plotting import scatter_matrix

# %%
df_fewer_columns = df.iloc[:,15:20:1]

# %%
scatter_matrix(df_fewer_columns, figsize=(12,12))
# Out:
# array([[<AxesSubplot:xlabel='green_zone_part', ylabel='green_zone_part'>,
#         <AxesSubplot:xlabel='indust_part', ylabel='green_zone_part'>,
#         <AxesSubplot:xlabel='children_preschool', ylabel='green_zone_part'>,
#         <AxesSubplot:xlabel='preschool_quota', ylabel='green_zone_part'>,
#         <AxesSubplot:xlabel='preschool_education_centers_raion', ylabel='green_zone_part'>],
#        [<AxesSubplot:xlabel='green_zone_part', ylabel='indust_part'>,
#         <AxesSubplot:xlabel='indust_part', ylabel='indust_part'>,
#         <AxesSubplot:xlabel='children_preschool', ylabel='indust_part'>,
#         <AxesSubplot:xlabel='preschool_quota', ylabel='indust_part'>,
#         <AxesSubplot:xlabel='preschool_education_centers_raion', ylabel='indust_part'>],
#        [<AxesSubplot:xlabel='green_zone_part', ylabel='children_preschool'>,
#         <AxesSubplot:xlabel='indust_part', ylabel='children_preschool'>,
#         <AxesSubplot:xlabel='children_preschool', ylabel='children_preschool'>,
#         <AxesSubplot:xlabel='preschool_quota', ylabel='children_preschool'>,
#         <AxesSubplot:xlabel='preschool_education_centers_raion', ylabel='children_preschool'>],
#        [<AxesSubplot:xlabel='green_zone_part', ylabel='preschool_quota'>,
#         <AxesSubplot:xlabel='indust_part', ylabel='preschool_quota'>,
#         <AxesSubplot:xlabel='children_preschool', ylabel='preschool_quota'>,
#         <AxesSubplot:xlabel='preschool_quota', ylabel='preschool_quota'>,
#         <AxesSubplot:xlabel='preschool_education_centers_raion', ylabel='preschool_quota'>],
#        [<AxesSubplot:xlabel='green_zone_part', ylabel='preschool_education_centers_raion'>,
#         <AxesSubplot:xlabel='indust_part', ylabel='preschool_education_centers_raion'>,
#         <AxesSubplot:xlabel='children_preschool', ylabel='preschool_education_centers_raion'>,
#         <AxesSubplot:xlabel='preschool_quota', ylabel='preschool_education_centers_raion'>,
#         <AxesSubplot:xlabel='preschool_education_centers_raion', ylabel='preschool_education_centers_raion'>]],
#       dtype=object)

# %%
import missingno as msno

# %%
df_some_columns = df.iloc[:, 0:30:1]

# %%
msno.matrix(df_some_columns)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df_some_columns)
# Out:
# <AxesSubplot:>

# %%
limitPer = len(df_some_columns)* .80
df_some_columns.dropna(axis='columns',thresh= limitPer, inplace = True)

# %%
msno.bar(df_some_columns)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>
